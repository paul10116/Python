# %%
import pandas as pd
from urllib.request import  urlretrieve

# %% [markdown]
# **Pandas** provides functions to read data from file formats like CSV, Excel spreadsheets, HTML tables, JSON, SQL and more.

# %%
fifa_df= pd.read_csv("./gasprices.csv")

# %%
type(fifa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
fifa_df
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990       0.98    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
# %%time
fifa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           19 non-null     int64
#  1   Australia      19 non-null     float64
#  2   Canada         19 non-null     float64
#  3   France         19 non-null     float64
#  4   Germany        19 non-null     float64
#  5   Italy          19 non-null     float64
#  6   Japan          19 non-null     float64
#  7   Mexico         19 non-null     float64
#  8   South Korea    19 non-null     float64
#  9   UK             19 non-null     float64
#  10  USA            19 non-null     float64
#  11  ger_aus_ratio  19 non-null     float64
# dtypes: float64(11), int64(1)
# memory usage: 1.9 KB
# CPU times: total: 15.6 ms
# Wall time: 10 ms

# %% [markdown]
# ==========================================================================

# %% [markdown]
# Using **.describe()** method can be seen info like mean, std, min/max values and number of non-empty values

# %%
fifa_df.describe()
# Out:
#               Year  Australia     Canada     France    Germany      Italy  \
# count    19.000000  19.000000  19.000000  19.000000  19.000000  19.000000
# mean   1999.000000   2.276842   2.086842   4.407895   4.224737   4.645789
# std       5.627314   0.880038   0.786618   1.167531   1.425749   1.146610
# min    1990.000000   0.980000   1.380000   3.410000   2.650000   3.570000
# 25%    1994.500000   1.745000   1.590000   3.605000   3.370000   3.805000
# 50%    1999.000000   1.950000   1.730000   3.870000   3.530000   4.390000
# 75%    2003.500000   2.455000   2.180000   4.700000   4.915000   4.940000
# max    2008.000000   4.450000   4.080000   7.510000   7.750000   7.630000
#
#            Japan     Mexico  South Korea         UK        USA  ger_aus_ratio
# count  19.000000  19.000000    19.000000  19.000000  19.000000      19.000000
# mean    3.820526   1.781579     3.835789   4.392632   1.592105       1.900455
# ...

# %%
fifa_df.shape #rows and columns
# Out:
# (19, 12)

# %%
fifa_df.columns
# Out:
# Index(['Year', 'Australia', 'Canada', 'France', 'Germany', 'Italy', 'Japan',
#        'Mexico', 'South Korea', 'UK', 'USA', 'ger_aus_ratio'],
#       dtype='object')

# %%
australia = fifa_df["Australia"]
germany = fifa_df["Germany"]
ratio = germany/australia

# %%
ratio
# Out:
# 0     2.704082
# 1     1.479592
# 2     1.730159
# 3     1.774566
# 4     1.913043
# 5     2.030769
# 6     1.858491
# 7     1.721951
# 8     2.049080
# 9     1.988372
# 10    1.778351
# 11    1.988304
# 12    2.085227
# 13    2.095890
# 14    1.926471
# 15    1.752322
# 16    1.703390
# 17    1.787013
# 18    1.741573
# dtype: float64

# %% [markdown]
# ===============================================================================

# %% [markdown]
# Specific values can be retrieved with indexing notatio **[]** or **at** method:

# %%
fifa_df["Canada"][11]
# Out:
# 1.72

# %%
fifa_df.at[11, "Canada"]
# Out:
# 1.72

# %% [markdown]
# ==================================================================

# %% [markdown]
# To take two columns info to compare use **[["first column", "second column"]]** :

# %%
aus_ger_ratio=fifa_df[["Year", "Australia", "Germany"]]

# %%
type(aus_ger_ratio)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ===========================================================================

# %% [markdown]
# To make full copy of the data frame use **copy()** method:

# %%
gas_prices= fifa_df.copy()

# %%
type(gas_prices)
# Out:
# pandas.core.frame.DataFrame

# %%
gas_prices
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990       0.98    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %% [markdown]
# ===========================================================================

# %% [markdown]
# To get one row of information use **loc[index]** indexing method:

# %%
gas_prices.loc[3]
# Out:
# Year             1993.000000
# Australia           1.730000
# Canada              1.570000
# France              3.410000
# Germany             3.070000
# Italy               3.680000
# Japan               4.160000
# Mexico              1.560000
# South Korea         2.880000
# UK                  2.840000
# USA                 1.110000
# ger_aus_ratio       1.774566
# Name: 3, dtype: float64

# %%
type(gas_prices.loc[2])
# Out:
# pandas.core.series.Series

# %% [markdown]
# =================================================================================

# %% [markdown]
# First five rows to get method is called **head()**. First last rows to get **tail()** method:

# %%
gas_prices.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990       0.98    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA  ger_aus_ratio
# 0         2.05  2.82  1.16       2.704082
# 1         2.49  3.01  1.14       1.479592
# 2         2.65  3.06  1.13       1.730159
# 3         2.88  2.84  1.11       1.774566
# 4         2.87  2.99  1.11       1.913043

# %%
gas_prices.head(3)
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990       0.98    1.87    3.63     2.65   4.59   3.16     1.0
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46     1.3
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58     1.5
#
#    South Korea    UK   USA  ger_aus_ratio
# 0         2.05  2.82  1.16       2.704082
# 1         2.49  3.01  1.14       1.479592
# 2         2.65  3.06  1.13       1.730159

# %% [markdown]
# ======================================================

# %% [markdown]
# The distinction between 0 and NaN is subtle but important. By using **first_valid_index()** method can be found the first index that doesn't contain a NaN value:

# %%
gas_prices["Australia"].first_valid_index()
# Out:
# 0

# %% [markdown]
# ===========================================================================

# %% [markdown]
# ### Sorting and quering rows

# %% [markdown]
# Boolean expressions can be used to check which rows satisfy criterion. The result is data frame with a subset of rows from the original:

# %%
high_gas_prices = gas_prices["UK"] > 6

# %%
gas_prices[high_gas_prices]
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA  ger_aus_ratio
# 16         5.92  6.36  2.59       1.703390
# 17         6.21  7.13  2.80       1.787013
# 18         5.83  7.42  3.27       1.741573

# %%
high_gas_prices_at_UK = gas_prices[gas_prices["UK"]>6]

# %%
high_gas_prices_at_UK
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA  ger_aus_ratio
# 16         5.92  6.36  2.59       1.703390
# 17         6.21  7.13  2.80       1.787013
# 18         5.83  7.42  3.27       1.741573

# %%
gas_prices.sort_values('Canada', ascending=True).head(5)
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 8  1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 9  1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 5  1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
#
#    South Korea    UK   USA  ger_aus_ratio
# 8         3.04  4.06  1.06       2.049080
# 4         2.87  2.99  1.11       1.913043
# 9         3.80  4.29  1.17       1.988372
# 5         2.94  3.21  1.15       2.030769
# 3         2.88  2.84  1.11       1.774566

# %% [markdown]
# ===========================================================================

# %% [markdown]
# making new column in data frame:

# %% [markdown]
# ========================================================================

# %% [markdown]
# Changing value in the middle of data:

# %%
gas_prices.at[0, "Australia"]=gas_prices.at[1, "Australia"]/2

# %%
gas_prices=fifa_df.copy()

# %%
gas_prices
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990       0.98    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
gas_prices['ger_aus_ratio']=ratio

# %%
gas_prices.at[0, "ger_aus_ratio"]=gas_prices.at[0, "Germany"] / gas_prices.at[0, "Australia"]

# %%
gas_prices
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990       0.98    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %% [markdown]
# ============================================================================

# %% [markdown]
# ### Saving changes

# %% [markdown]
# To write the data from the data frame into a file can be used **to_csv('file name', index = none)** function. Pass **index = None** to remove indexing column additionally created by **pandas**.

# %%
gas_prices.to_csv("gasprices.csv", index=None)

# %%
gas_prices.Australia.plot()
gas_prices.Germany.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ========================================================================

# %% [markdown]
# While this plot shows the overall trend, there is no dates on **X** axis. Date column can be used to address this issue:

# %%
gas_prices.set_index("Year", inplace=True)

# %%
gas_prices.Australia.plot(title="Australia", kind="bar")
# Out:
# <AxesSubplot: title={'center': 'Australia'}, xlabel='Year'>
